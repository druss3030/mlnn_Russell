# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import pandas
import numpy

# %%
# %matplotlib inline
import matplotlib.pylab as plt

# %%
plt.plot([0,0,1,2,3,4,5], [2,2,3,3,4,5,6])

# %%
plt.scatter([0,0,1,2,3,4,5], [2,2,3,3,4,5,6])
